# %%
#precious LAB PROJECT--------------------Python Codes-------------------------------------------------------------
#Observation DATA------------------GPCP, TRMM and CRU-------------------------------------------
DAMIP.CCCma.CanESM5.ssp245-aer.

# %% [markdown]
# ***Evaluating the role of Anthropogenic Aerosols and Greenhouse gases in Future precipitaton extremes over West Africa***
#
# ---

# %% [markdown]
#  SELECTED CIMP6 CLIMATE MODELS with aeorosols and Green house experiment (2020)
#
#
# 1.   CCSM4.0
# 2.   CESM1 CAM5
# 3.   CSIRO Mk3.6.0
# 4.   CSIRO Mk3.6.0,
# 5.   FGOALS-g2,
# 6.   GFDL-CM3,
# 7.   GFDL-ESM2M,
# 8.   GISS-E2-H,
# 9.   GISS-E2-R,
# 10.  IPSL-CM5A-LR,
# 11.  NorESM1-M
# 12.  CanESM2

# %%
### opening NETCDF dataset MERRA###
### Import libraries###

import matplotlib.pyplot as plt 
from mpl_toolkits.basemap import Basemap
from netCDF4 import Dataset
import numpy as np
file = '/content/drive/MyDrive/avgNG_cdd.nc'
fh = Dataset(file, mode = 'r')

# %%
### Get variables ###
# Read in 'T2M' 2-meter air temperature variable.
lons = fh.variables['lon'][:] # get longitude variables
lats = fh.variables['lat'][:] # get latitude variables
tmean = fh.variables['CDD'][:,:,:]

# %%
print(fh)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     CDI: Climate Data Interface version 1.9.9rc1 (https://mpimet.mpg.de/cdi)
#     Conventions: CF-1.4
#     history: Mon Sep 20 08:39:27 2021: cdo timavg NG_cdd.nc avgNG_cdd.nc
# Sun Sep 19 03:53:05 2021: cdo invertlat 1_cdd.nc NG_cdd.nc
#     created_by: R, packages ncdf4 and raster (version 3.4-13)
#     date: 2021-09-19 03:50:44
#     CDO: Climate Data Operators version 1.9.9rc1 (https://mpimet.mpg.de/cdo)
#     dimensions(sizes): time(1), bnds(2), lon(60), lat(44)
#     variables(dimensions): float64 time(time), float64 time_bnds(time, bnds), float64 lon(lon), float64 lat(lat), int32 crs(), float32 CDD(time, lat, lon)
#     groups:

# %%
print(fh)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     CDI: Climate Data Interface version 1.6.4 (http://code.zmaw.de/projects/cdi)
#     Conventions: CF-1.4
#     history: Wed Sep 01 09:47:36 2021: C:\cygwin\bin\cdo.exe timavg JJAS_gpcc.nc aveJJAS_gpcc.nc
# Sun Aug 29 16:29:12 2021: C:\cygwin\bin\cdo.exe selmon,6,7,8,9 gp2.nc JJAS_gpcc.nc
# Sun Aug 29 16:27:50 2021: C:\cygwin\bin\cdo.exe selyear,1988/2013 gpcc1.nc gp2.nc
#     institution: Deutscher Wetterdienst
#     Info: Created with the CM SAF R Toolbox.
# ...

# %%
### Import libraries###

import matplotlib.pyplot as plt 
from mpl_toolkits.basemap import Basemap
from netCDF4 import Dataset
import numpy as np
file = '/content/drive/MyDrive/extreme_indices/jjas_R20mm.nc'
fh = Dataset(file, mode = 'r')

# %%
### Get variables ###
# Read in 'T2M' 2-meter air temperature variable.
fh6=Dataset('/content/drive/MyDrive/aveJJAS_gpcc.nc',mode='r')
lons = fh6.variables['lon'][:] # get longitude variables
lats = fh6.variables['lat'][:] # get latitude variables
t6 = fh6.variables['prcp'][:,:,:]

# %%
# !apt-get install -q libgeos-3.5.0
# !apt-get install -q libgeos-dev
# !pip install -q https://github.com/matplotlib/basemap/archive/master.zip
# !pip install -q pyproj==1.9.6
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# E: Unable to locate package libgeos-3.5.0
# E: Couldn't find any package by glob 'libgeos-3.5.0'
# E: Couldn't find any package by regex 'libgeos-3.5.0'
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libgeos-dev is already the newest version (3.6.2-1build2).
# libgeos-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
#      | 133.1 MB 379 kB/s
#      |████████████████████████████████| 6.3 MB 5.0 MB/s
#      |████████████████████████████████| 219 kB 67.5 MB/s
# ...
#      |████████████████████████████████| 2.8 MB 5.2 MB/s
# ...

# %%
fh1=Dataset('/content/drive/MyDrive/extreme_indices/jjas_CWD.nc',mode='r')
fh2=Dataset('/content/drive/MyDrive/extreme_indices/jjas_CDD.nc',mode='r')
fh3=Dataset('/content/drive/MyDrive/extreme_indices/jjas_Rx5day.nc',mode='r')
fh4=Dataset('/content/drive/MyDrive/extreme_indices/jjas_SDII.nc',mode='r')
fh5=Dataset('/content/drive/MyDrive/extreme_indices/jjas_prcptot.nc',mode='r')

# %%
fh1=Dataset('/content/drive/MyDrive/mam_extreme/mamCWD.nc',mode='r')
fh2=Dataset('/content/drive/MyDrive/mam_extreme/mamCDD.nc',mode='r')
fh3=Dataset('/content/drive/MyDrive/mam_extreme/mamRx5day.nc',mode='r')
fh4=Dataset('/content/drive/MyDrive/mam_extreme/mamsdii.nc',mode='r')
fh5=Dataset('/content/drive/MyDrive/mam_prctot',mode='r')

# %%
print(fh5)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     CDI: Climate Data Interface version 1.6.4 (http://code.zmaw.de/projects/cdi)
#     Conventions: CF-1.4
#     history: Wed Sep 01 17:19:04 2021: C:\cygwin\bin\cdo.exe eca_rr1 m1.nc mam_prctot
# Wed Sep 01 15:20:42 2021: C:\cygwin\bin\cdo.exe selyear,1988/2013 mask_MAM.nc m1.nc
# Sat Aug 14 03:29:42 2021: cdo selmon,3,4,5 masked_pr.nc mask_MAM.nc
# Sat Aug 14 03:28:17 2021: cdo mul pr_ens.nc seamask.nc masked_pr.nc
# Sat Aug 14 03:12:20 2021: cdo ensmean pr_BCC_lonlat.nc pr_CanESM5_lonlat.nc pr_CESM2_lonlat.nc pr_CNRM_lonlat.nc pr_Hadgem3_lonlat.nc pr_IPSL_lonlat.nc pr_MPI_ESM1_lonlat.nc pr_NESM3_lonlat.nc pr_ens.nc
# Sat Aug 14 03:04:58 2021: cdo remapbil,griddes pr_BCC.nc pr_BCC_lonlat.nc
#     CDO: Climate Data Operators version 1.6.4 (http://code.zmaw.de/projects/cdo)
#     dimensions(sizes): lon(91), lat(46), time(1)
# ...

# %%
### Get variables ###
# Read in 'T2M' 2-meter air temperature variable.
fh=Dataset('/content/drive/MyDrive/extreme_indices/jjas_R20mm.nc',mode='r')
lons = fh.variables['lon'][:] # get longitude variables
lats = fh.variables['lat'][:] # get latitude variables
tmean = fh.variables['very_heavy_precipitation_days_index_per_time_period'][:,:,:]

# %%
t1 = fh1.variables['consecutive_wet_days_index_per_time_period'][:,:,:]
t2 = fh2.variables['consecutive_dry_days_index_per_time_period'][:,:,:] 
t3 = fh3.variables['highest_five_day_precipitation_amount_per_time_period'][:,:,:] 
t4 = fh4.variables['simple_daily_intensitiy_index_per_time_period'][:,:,:] 
t5 = fh5.variables['wet_days_index_per_time_period'][:,:,:]

# %%
### meshgrid ###
lon, lat = np.meshgrid(lons, lats) # create a matrix of coordinates





# create new figure
#fig=plt.figure()
#fig,ax=plt.subplots(figsize=(9,10))
fig, ax= plt.subplots(nrows=3, ncols=2)
[axi.set_axis_off() for axi in ax.ravel()]


# panel 1
m=Basemap(projection='cyl',llcrnrlat=0,urcrnrlat=20,llcrnrlon=-20,urcrnrlon=20,resolution='h')
xi,yi = m(lon,lat)
ax = fig.add_subplot(321)
fig.set_figheight(9)
fig.set_figwidth(10)
cs = m.contourf(xi,yi,np.squeeze(t1),  cmap='viridis',extend='both') 
m.drawmapboundary()
m.drawcountries()
m.drawparallels(np.arange(0, 20, 6), labels=[1,0,0,0]) # draw parallels
m.drawmeridians(np.arange(-20, 20, 6), labels=[0,0,0,1]) # draw meridians
m.colorbar(location='bottom', pad="35%")
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('CWD', fontweight='bold', fontsize=10)
ax.text(-18, 0.5, 'CWD (days)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


# panel 2
m1=Basemap(projection='cyl',llcrnrlat=0,urcrnrlat=20,llcrnrlon=-20,urcrnrlon=20,resolution='h')
xi,yi = m1(lon,lat)
ax = fig.add_subplot(322)
#fig.set_figheight(9)
fig.set_figwidth(10)
cs = m1.contourf(xi,yi,np.squeeze(t2),  cmap='viridis',extend='both') 
m1.drawmapboundary()
m1.drawcountries()
m1.drawparallels(np.arange(0, 20, 6), labels=[1,0,0,0]) # draw parallels
m1.drawmeridians(np.arange(-20, 20, 6), labels=[0,0,0,1]) # draw meridians
m1.colorbar(location='bottom', pad="35%")
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('CDD', fontweight='bold', fontsize=10)
ax.text(-18, 0.5, 'CDD (days)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})

# panel 3
ax = fig.add_subplot(323)
#fig.set_figheight(9)
fig.set_figwidth(10)
m2=Basemap(projection='cyl',llcrnrlat=0,urcrnrlat=20,llcrnrlon=-20,urcrnrlon=20,resolution='h')
xi,yi = m2(lon,lat)
cs = m2.contourf(xi,yi,np.squeeze(t3),  cmap='viridis',extend='both') 
m2.drawmapboundary()
m2.drawcountries()
m2.drawparallels(np.arange(0, 20, 6), labels=[1,0,0,0]) # draw parallels
m2.drawmeridians(np.arange(-20, 20, 6), labels=[0,0,0,1]) # draw meridians
m2.colorbar(location='bottom', pad="35%")
#cbar.set_label('mm') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('Rx5day', fontweight='bold', fontsize=10)
ax.text(-18, 0.5, 'Rx5day (mm)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


ax = fig.add_subplot(324)
#fig.set_figheight(9)
fig.set_figwidth(10)
m3=Basemap(projection='cyl',llcrnrlat=0,urcrnrlat=20,llcrnrlon=-20,urcrnrlon=20,resolution='h')
xi,yi = m3(lon,lat)
cs = m3.contourf(xi,yi,np.squeeze(t4),  cmap='viridis',extend='both') 
m3.drawmapboundary()
m3.drawcountries()
m3.drawparallels(np.arange(0, 20, 6), labels=[1,0,0,0]) # draw parallels
m3.drawmeridians(np.arange(-20, 20, 6), labels=[0,0,0,1]) # draw meridians
m3.colorbar(location='bottom', pad="35%")
#cbar.set_label('mm/day') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('SDII', fontweight='bold', fontsize=10)
ax.text(-18, 0.5, 'SDII (mm/day)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


ax = fig.add_subplot(325)
#fig.set_figheight(9)
fig.set_figwidth(10)
m4=Basemap(projection='cyl',llcrnrlat=0,urcrnrlat=20,llcrnrlon=-20,urcrnrlon=20,resolution='h')
xi,yi = m4(lon,lat)
cs = m4.contourf(xi,yi,np.squeeze(tmean),  cmap='viridis',extend='both') 
m4.drawmapboundary()
m4.drawcountries()
m4.drawparallels(np.arange(0, 20, 6), labels=[1,0,0,0]) # draw parallels
m4.drawmeridians(np.arange(-20, 20, 6), labels=[0,0,0,1]) # draw meridians
m4.colorbar(location='bottom', pad="35%")
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('R20mm', fontweight='bold', fontsize=10)
ax.text(-18, 0.5, 'R2Omm (days)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})

ax = fig.add_subplot(326)
#fig.set_figheight(9)
fig.set_figwidth(10)
m5=Basemap(projection='cyl',llcrnrlat=0,urcrnrlat=20,llcrnrlon=-20,urcrnrlon=20,resolution='h')
xi,yi = m5(lon,lat)
cs = m5.contourf(xi,yi,np.squeeze(t5),  cmap='viridis',extend='both')
#m5.drawcoastlines(color="aqua") 
m5.drawmapboundary()
m5.drawcountries()
m5.drawparallels(np.arange(0, 20, 6), labels=[1,0,0,0,]) # draw parallels
m5.drawmeridians(np.arange(-20, 20, 6), labels=[0,0,0,1]) # draw meridians
m5.colorbar(location='bottom', pad="35%")
#cbar.set_label('mm') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('PRCPTOT', fontweight='bold', fontsize=10)
ax.text(-18, 0.5, 'PRCPTOT(mm)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 0.5})

# Show the plot

plt.savefig('/content/drive/MyDrive/extreme_indices/ex23.jpg',bbox_inches='tight')
plt.savefig('/content/drive/extreme_indices/ex4.jpg')

# %%
### meshgrid ###
lon, lat = np.meshgrid(lons, lats) # create a matrix of coordinates





# create new figure
#fig=plt.figure()
#fig,ax=plt.subplots(figsize=(9,10))
fig, ax= plt.subplots(nrows=1, ncols=2)
[axi.set_axis_off() for axi in ax.ravel()]


# panel 1
m=Basemap(projection='cyl',llcrnrlat=0,urcrnrlat=20,llcrnrlon=-20,urcrnrlon=20,resolution='h')
xi,yi = m(lon,lat)
ax = fig.add_subplot(121)
fig.set_figheight(9)
fig.set_figwidth(10)
cs = m.contourf(xi,yi,np.squeeze(t6),  cmap='rainbow',extend='both') 
m.drawmapboundary()
m.drawcountries()
m.drawparallels(np.arange(0, 20, 6), labels=[1,0,0,0]) # draw parallels
m.drawmeridians(np.arange(-20, 20, 6), labels=[0,0,0,1]) # draw meridians
m.colorbar(location='bottom', pad="35%")
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('CWD', fontweight='bold', fontsize=10)
ax.text(-19.8, 0.5, 'JJAS (mm/day)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


# panel 2
m1=Basemap(projection='cyl',llcrnrlat=0,urcrnrlat=20,llcrnrlon=-20,urcrnrlon=20,resolution='h')
xi,yi = m1(lon,lat)
ax = fig.add_subplot(122)
#fig.set_figheight(9)
fig.set_figwidth(10)
cs = m1.contourf(xi,yi,np.squeeze(tmean),  cmap='rainbow',extend='both') 
m1.drawmapboundary()
m1.drawcountries()
m1.drawparallels(np.arange(0, 20, 6), labels=[1,0,0,0]) # draw parallels
m1.drawmeridians(np.arange(-20, 20, 6), labels=[0,0,0,1]) # draw meridians
m1.colorbar(location='bottom', pad="35%")
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('CDD', fontweight='bold', fontsize=10)
ax.text(-19.8, 0.5, 'MAM (mm/day)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})

plt.savefig('/content/drive/MyDrive/extreme_indices/combined1.jpg',bbox_inches='tight')

# %%
### meshgrid ###

m=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=15,llcrnrlon=3,urcrnrlon=14,resolution='h')
lon, lat = np.meshgrid(lons, lats) # create a matrix of coordinates
xi, yi = m(lon, lat)

# Plot Data

fig,ax=plt.subplots(figsize=(9,10))
#cs1 = m.contourf(xi,yi,np.squeeze(tmean),  cmap='rainbow') 

cs = m.contourf(xi,yi,np.squeeze(tmean),  cmap='viridis',extend='both') 


m.drawcoastlines(color='aqua')
m.drawmapboundary()
#m.drawcountries()
#m.fillcontinents()
m.drawstates()

#m.drawlsmask()
### Draw Coordinates ###

m.drawparallels(np.arange(0, 14, 4), labels=[1,0,0,0]) # draw parallels
m.drawmeridians(np.arange(3, 15, 4), labels=[0,0,0,1]) # draw meridians

# Add Colorbar
cbar = m.colorbar(cs,location="bottom", pad="15%")
#cbar.set_label('mm/day') # tmean units

### Labels ###
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)

### Add Title ###
#plt.title('R10mm', fontweight='bold', fontsize=12)
ax.text(3,4, 'CDD', style='italic',fontsize=15,       
        bbox={'facecolor': 'white', 'alpha':0.8, 'pad': 0.5})

# Show the plot
#plt.show()
plt.savefig('/content/drive/MyDrive/tas/tas85.jpg',bbox_inches='tight')

# %%
### opening NETCDF dataset MERRA###
### Import libraries###

import matplotlib.pyplot as plt 
from mpl_toolkits.basemap import Basemap
from netCDF4 import Dataset
import numpy as np

# %%
print(fh6)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     CDI: Climate Data Interface version 1.9.9rc1 (https://mpimet.mpg.de/cdi)
#     Conventions: CF-1.4
#     history: Mon Sep 20 11:22:24 2021: cdo timavg NG_r1mm.nc avg_r1mm.nc
# Sun Sep 19 03:55:58 2021: cdo invertlat 4_r1mm.nc NG_r1mm.nc
#     created_by: R, packages ncdf4 and raster (version 3.4-13)
#     date: 2021-09-19 03:51:01
#     CDO: Climate Data Operators version 1.9.9rc1 (https://mpimet.mpg.de/cdo)
#     dimensions(sizes): time(1), bnds(2), lon(60), lat(44)
#     variables(dimensions): float64 time(time), float64 time_bnds(time, bnds), float64 lon(lon), float64 lat(lat), int32 crs(), float32 R1MM(time, lat, lon)
#     groups:

# %%
fh1=Dataset('/content/drive/MyDrive/cdd/avgNG_cdd.nc',mode='r')
fh2=Dataset('/content/drive/MyDrive/cdd/bias1_cdd.nc',mode='r')
fh3=Dataset('/content/drive/MyDrive/cdd/bias2_cdd.nc',mode='r')

t1 = fh1.variables['CDD'][:,:,:]
t2 = fh2.variables['CDD'][:,:,:] 
t3 = fh3.variables['CDD'][:,:,:] 

lons = fh1.variables['lon'][:] # get longitude variables
lats = fh1.variables['lat'][:] # get latitude variables

# %%
fh1=Dataset('/content/drive/MyDrive/indicesData/cwd/avgNG_cwd.nc',mode='r')
fh2=Dataset('/content/drive/MyDrive/indicesData/cwd/bias1_cwd.nc',mode='r')
fh3=Dataset('/content/drive/MyDrive/indicesData/cwd/bias2_cwd.nc',mode='r')

t1 = fh1.variables['CDD'][:,:,:]
t2 = fh2.variables['CDD'][:,:,:] 
t3 = fh3.variables['CDD'][:,:,:] 

lons = fh1.variables['lon'][:] # get longitude variables
lats = fh1.variables['lat'][:] # get latitude variables

# %%
fh1=Dataset('/content/drive/MyDrive/indicesData/prcptot/avg_prcptot.nc',mode='r')
fh2=Dataset('/content/drive/MyDrive/indicesData/prcptot/bias1_prcptot.nc',mode='r')
fh3=Dataset('/content/drive/MyDrive/indicesData/prcptot/bias2_prcptot.nc',mode='r')

t1 = fh1.variables['PRCPTOT'][:,:,:]
t2 = fh2.variables['PRCPTOT'][:,:,:] 
t3 = fh3.variables['PRCPTOT'][:,:,:] 

lons = fh1.variables['lon'][:] # get longitude variables
lats = fh1.variables['lat'][:] # get latitude variables

# %%
fh1=Dataset('/content/drive/MyDrive/indicesData/r1mm/avg_r1mm.nc',mode='r')
fh2=Dataset('/content/drive/MyDrive/indicesData/r1mm/bias1_r1mm.nc',mode='r')
fh3=Dataset('/content/drive/MyDrive/indicesData/r1mm/bias2_r1mm.nc',mode='r')

t1 = fh1.variables['R1MM'][:,:,:]
t2 = fh2.variables['R1MM'][:,:,:] 
t3 = fh3.variables['R1MM'][:,:,:] 

lons = fh1.variables['lon'][:] # get longitude variables
lats = fh1.variables['lat'][:] # get latitude variables

# %%
fh1=Dataset('/content/drive/MyDrive/indicesData/r20mm/avg_r20mm.nc',mode='r')
fh2=Dataset('/content/drive/MyDrive/indicesData/r20mm/bias1_r20mm.nc',mode='r')
fh3=Dataset('/content/drive/MyDrive/indicesData/r20mm/bias2_r20mm.nc',mode='r')

t1 = fh1.variables['R20MM'][:,:,:]
t2 = fh2.variables['R20MM'][:,:,:] 
t3 = fh3.variables['R20MM'][:,:,:] 

lons = fh1.variables['lon'][:] # get longitude variables
lats = fh1.variables['lat'][:] # get latitude variables

# %%
fh1=Dataset('/content/drive/MyDrive/indicesData/rx5day/avg_rx5day.nc',mode='r')
fh2=Dataset('/content/drive/MyDrive/indicesData/rx5day/bias1_rx5day.nc',mode='r')
fh3=Dataset('/content/drive/MyDrive/indicesData/rx5day/bias2_rx5day.nc',mode='r')

t1 = fh1.variables['RX5DAY'][:,:,:]
t2 = fh2.variables['RX5DAY'][:,:,:] 
t3 = fh3.variables['RX5DAY'][:,:,:] 

lons = fh1.variables['lon'][:] # get longitude variables
lats = fh1.variables['lat'][:] # get latitude variables

# %%
fh1=Dataset('/content/drive/MyDrive/indicesData/r99p/avg_r99p.nc',mode='r')
fh2=Dataset('/content/drive/MyDrive/indicesData/r99p/bias1_r99p.nc',mode='r')
fh3=Dataset('/content/drive/MyDrive/indicesData/r99p/bias2_r99p.nc',mode='r')

t1 = fh1.variables['R99PTOT'][:,:,:]
t2 = fh2.variables['R99PTOT'][:,:,:] 
t3 = fh3.variables['R99PTOT'][:,:,:] 

lons = fh1.variables['lon'][:] # get longitude variables
lats = fh1.variables['lat'][:] # get latitude variables

# %%
fh1=Dataset('/content/drive/MyDrive/indicesData/sdii/avg_sdii.nc',mode='r')
fh2=Dataset('/content/drive/MyDrive/indicesData/sdii/bias1_sdii.nc',mode='r')
fh3=Dataset('/content/drive/MyDrive/indicesData/sdii/bias2_sdii.nc',mode='r')

t1 = fh1.variables['SDII'][:,:,:]
t2 = fh2.variables['SDII'][:,:,:] 
t3 = fh3.variables['SDII'][:,:,:] 

lons = fh1.variables['lon'][:] # get longitude variables
lats = fh1.variables['lat'][:] # get latitude variables

# %%
fh1=Dataset('/content/drive/MyDrive/nigeriaIndices/avgNG_cdd.nc',mode='r')
fh2=Dataset('/content/drive/MyDrive/nigeriaIndices/avgNG_cwd.nc',mode='r')
fh3=Dataset('/content/drive/MyDrive/nigeriaIndices/avg_prcptot.nc',mode='r')
fh4=Dataset('/content/drive/MyDrive/nigeriaIndices/avg_r10mm.nc',mode='r')
fh5=Dataset('/content/drive/MyDrive/nigeriaIndices/avg_r20mm.nc',mode='r')
fh6=Dataset('/content/drive/MyDrive/nigeriaIndices/avg_r1mm.nc',mode='r')

# %%
t1 = fh1.variables['CDD'][:,:,:]
t2 = fh2.variables['CDD'][:,:,:] 
t3 = fh3.variables['PRCPTOT'][:,:,:] 
t4 = fh4.variables['R10MM'][:,:,:] 
t5 = fh5.variables['R20MM'][:,:,:] 
t6 = fh6.variables['R1MM'][:,:,:]

# %%
lons = fh1.variables['lon'][:] # get longitude variables
lats = fh1.variables['lat'][:] # get latitude variables

# %%
### meshgrid ###
lon, lat = np.meshgrid(lons, lats) # create a matrix of coordinates





# create new figure
#fig=plt.figure()
#fig,ax=plt.subplots(figsize=(9,10))
#fig, ax= plt.subplots(nrows=3, ncols=2)
#[axi.set_axis_off() for axi in ax.ravel()]

f = plt.figure(figsize=(9,20))

# panel 1
m=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=15,llcrnrlon=3,urcrnrlon=14,resolution='h')
xi,yi = m(lon,lat)
ax = f.add_subplot(321)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m.contourf(xi,yi,np.squeeze(t1),  cmap='viridis',extend='both') 
m.drawmapboundary()
#m.drawcountries()
m.drawparallels(np.arange(0, 14, 4), labels=[1,0,0,0]) # draw parallels
m.drawmeridians(np.arange(3, 15, 4), labels=[0,0,0,1]) # draw meridians
m.colorbar(location='bottom', pad="35%")
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('CWD', fontweight='bold', fontsize=10)
ax.text(3,4, 'CDD (days)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


# panel 2
m1=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=15,llcrnrlon=3,urcrnrlon=14,resolution='h')
xi,yi = m1(lon,lat)
ax1 = f.add_subplot(322)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m1.contourf(xi,yi,np.squeeze(t2),  cmap='viridis',extend='both') 
m1.drawmapboundary()
#m1.drawcountries()
m1.drawparallels(np.arange(0, 14, 4), labels=[1,0,0,0]) # draw parallels
m1.drawmeridians(np.arange(3, 15, 4), labels=[0,0,0,1]) # draw meridians
m1.colorbar(location='bottom', pad="35%")
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('CDD', fontweight='bold', fontsize=10)
ax1.text(3,4, 'CWD (days)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})

# panel 3
ax2 = f.add_subplot(323)
#fig.set_figheight(9)
#fig.set_figwidth(10)
m2=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=15,llcrnrlon=3,urcrnrlon=14,resolution='h')
xi,yi = m2(lon,lat)
cs = m2.contourf(xi,yi,np.squeeze(t3),  cmap='viridis',extend='both') 
m2.drawmapboundary()
#m2.drawcountries()
m2.drawparallels(np.arange(0, 14, 4), labels=[1,0,0,0]) # draw parallels
m2.drawmeridians(np.arange(3, 15, 4), labels=[0,0,0,1]) # draw meridians
m2.colorbar(location='bottom', pad="35%")
#cbar.set_label('mm') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('Rx5day', fontweight='bold', fontsize=10)
ax2.text(3,4, 'PRCPTOT (mm)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


ax3 = f.add_subplot(324)
#fig.set_figheight(9)
#fig.set_figwidth(10)
m3=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=15,llcrnrlon=3,urcrnrlon=14,resolution='h')
xi,yi = m3(lon,lat)
cs = m3.contourf(xi,yi,np.squeeze(t4),  cmap='viridis',extend='both') 
m3.drawmapboundary()
#m3.drawcountries()
m3.drawparallels(np.arange(0, 14, 4), labels=[1,0,0,0]) # draw parallels
m3.drawmeridians(np.arange(3, 15, 4), labels=[0,0,0,1]) # draw meridians
m3.colorbar(location='bottom', pad="35%")
#cbar.set_label('mm/day') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('SDII', fontweight='bold', fontsize=10)
ax3.text(3,4, 'R10mm (days)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


ax4 = f.add_subplot(325)
#fig.set_figheight(9)
#fig.set_figwidth(10)
m4=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=15,llcrnrlon=3,urcrnrlon=14,resolution='h')
xi,yi = m4(lon,lat)
cs = m4.contourf(xi,yi,np.squeeze(t5),  cmap='viridis',extend='both') 
m4.drawmapboundary()
#m4.drawcountries()
m4.drawparallels(np.arange(0, 14, 4), labels=[1,0,0,0]) # draw parallels
m4.drawmeridians(np.arange(3, 15, 4), labels=[0,0,0,1]) # draw meridians
m4.colorbar(location='bottom', pad="35%")
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('R20mm', fontweight='bold', fontsize=10)
ax4.text(3,4, 'R2Omm (days)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})

ax5 = f.add_subplot(326)
#fig.set_figheight(9)
#fig.set_figwidth(10)
m5=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=15,llcrnrlon=3,urcrnrlon=14,resolution='h')
xi,yi = m5(lon,lat)
cs = m5.contourf(xi,yi,np.squeeze(t6),  cmap='viridis',extend='both')
#m5.drawcoastlines(color="aqua") 
m5.drawmapboundary()
#m5.drawcountries()
m5.drawparallels(np.arange(0, 14, 4), labels=[1,0,0,0]) # draw parallels
m5.drawmeridians(np.arange(3, 15, 4), labels=[0,0,0,1]) # draw meridians
m5.colorbar(location='bottom', pad="35%")
#cbar.set_label('mm') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=15)
plt.ylabel('Latitude', fontweight='bold', labelpad=25)
#plt.title('PRCPTOT', fontweight='bold', fontsize=10)
ax5.text(3,4, 'R1mm(days)', style='italic',
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 0.5})

# Show the plot

plt.savefig('/content/drive/MyDrive/extreme_indices/ex23.jpg',bbox_inches='tight')

# %%
### meshgrid ###
lon, lat = np.meshgrid(lons, lats) # create a matrix of coordinates





# create new figure
#fig=plt.figure()
#fig,ax=plt.subplots(figsize=(9,10))
#fig, ax= plt.subplots(nrows=3, ncols=2)
#[axi.set_axis_off() for axi in ax.ravel()]

f = plt.figure(figsize=(24,70))

# panel 1
m=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m(lon,lat)
ax = f.add_subplot(131)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m.contourf(xi,yi,np.squeeze(t1),  cmap='viridis',extend='both') 
m.drawmapboundary()
#m.drawcountries()
m.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m.colorbar(location='bottom', pad="15%")
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
plt.ylabel('Latitude', fontweight='bold', labelpad=35,fontsize=15)
plt.title('CDD', fontweight='bold', fontsize=16)
ax.text(3.3,3.4, 'CDD (days)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


# panel 2
m1=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m1(lon,lat)
ax1 = f.add_subplot(132)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m1.contourf(xi,yi,np.squeeze(t2),  cmap='rainbow',extend='both') 
m1.drawmapboundary()
#m1.drawcountries()
m1.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m1.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m1.colorbar(location='bottom', pad="15%")
#cbar.set_ticks([-8,-6,-4,-2,0,2,4,6,8])
cbar.set_ticklabels([-4,-2,0,2,4,6])
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D1-CDD', fontweight='bold', fontsize=16)
ax1.text(3.3,3.4, 'CDD (days)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})

# panel 3
ax2 = f.add_subplot(133)
#fig.set_figheight(9)
#fig.set_figwidth(10)
m2=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m2(lon,lat)
cs = m2.contourf(xi,yi,np.squeeze(t3),  cmap='rainbow',extend='both') 
m2.drawmapboundary()
#m2.drawcountries()
m2.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m2.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m2.colorbar(location='bottom', pad="15%")
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('mm') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D2-CDD', fontweight='bold', fontsize=16)
ax2.text(3.3,3.4, 'CDD (days)', style='italic', fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 2.0, 'pad': 2})


# Show the plot

plt.savefig('/content/drive/MyDrive/extreme_indices/p12.jpg',bbox_inches='tight')

# %%
### meshgrid ###
lon, lat = np.meshgrid(lons, lats) # create a matrix of coordinates





# create new figure
#fig=plt.figure()
#fig,ax=plt.subplots(figsize=(9,10))
#fig, ax= plt.subplots(nrows=3, ncols=2)
#[axi.set_axis_off() for axi in ax.ravel()]

f = plt.figure(figsize=(24,70))

# panel 1
m=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m(lon,lat)
ax = f.add_subplot(131)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m.contourf(xi,yi,np.squeeze(t1),  cmap='viridis',extend='both') 
m.drawmapboundary()
#m.drawcountries()
m.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m.colorbar(location='bottom', pad="15%")
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
plt.ylabel('Latitude', fontweight='bold', labelpad=35,fontsize=15)
plt.title('CWD', fontweight='bold', fontsize=16)
ax.text(3.3,3.4, 'CWD (days)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


# panel 2
m1=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m1(lon,lat)
ax1 = f.add_subplot(132)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m1.contourf(xi,yi,np.squeeze(t2),  cmap='rainbow',extend='both') 
m1.drawmapboundary()
#m1.drawcountries()
m1.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m1.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m1.colorbar(location='bottom', pad="15%")
#cbar.set_ticks([-8,-6,-4,-2,0,2,4,6,8])
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D1-CWD', fontweight='bold', fontsize=16)
ax1.text(3.3,3.4, 'CWD (days)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})

# panel 3
ax2 = f.add_subplot(133)
#fig.set_figheight(9)
#fig.set_figwidth(10)
m2=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m2(lon,lat)
cs = m2.contourf(xi,yi,np.squeeze(t3),  cmap='rainbow',extend='both') 
m2.drawmapboundary()
#m2.drawcountries()
m2.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m2.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m2.colorbar(location='bottom', pad="15%")
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('mm') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D2-CWD', fontweight='bold', fontsize=16)
ax2.text(3.3,3.4, 'CWD (days)', style='italic', fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 2.0, 'pad': 2})


# Show the plot

plt.savefig('/content/drive/MyDrive/extreme_indices/pr1.jpg',bbox_inches='tight')

# %%
### meshgrid ###
lon, lat = np.meshgrid(lons, lats) # create a matrix of coordinates





# create new figure
#fig=plt.figure()
#fig,ax=plt.subplots(figsize=(9,10))
#fig, ax= plt.subplots(nrows=3, ncols=2)
#[axi.set_axis_off() for axi in ax.ravel()]

f = plt.figure(figsize=(24,70))

# panel 1
m=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m(lon,lat)
ax = f.add_subplot(131)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m.contourf(xi,yi,np.squeeze(t1),  cmap='viridis',extend='both') 
m.drawmapboundary()
#m.drawcountries()
m.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m.colorbar(location='bottom', pad="15%")
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
plt.ylabel('Latitude', fontweight='bold', labelpad=35,fontsize=15)
plt.title('PRCPTOT', fontweight='bold', fontsize=16)
ax.text(3.3,3.4, 'PRCPTOT (mm)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


# panel 2
m1=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m1(lon,lat)
ax1 = f.add_subplot(132)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m1.contourf(xi,yi,np.squeeze(t2),  cmap='rainbow',extend='both') 
m1.drawmapboundary()
#m1.drawcountries()
m1.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m1.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m1.colorbar(location='bottom', pad="15%")
#cbar.set_ticks([-8,-6,-4,-2,0,2,4,6,8])
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D1-PRCPTOT', fontweight='bold', fontsize=16)
ax1.text(3.3,3.4, 'PRCPTOT (mm)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})

# panel 3
ax2 = f.add_subplot(133)
#fig.set_figheight(9)
#fig.set_figwidth(10)
m2=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m2(lon,lat)
cs = m2.contourf(xi,yi,np.squeeze(t3),  cmap='rainbow',extend='both') 
m2.drawmapboundary()
#m2.drawcountries()
m2.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m2.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m2.colorbar(location='bottom', pad="15%")
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('mm') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D2-PRCPTOT', fontweight='bold', fontsize=16)
ax2.text(3.3,3.4, 'PRCPTOT (mm)', style='italic', fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 2.0, 'pad': 2})


# Show the plot

plt.savefig('/content/drive/MyDrive/extreme_indices/pr2.jpg',bbox_inches='tight')

# %%
### meshgrid ###
lon, lat = np.meshgrid(lons, lats) # create a matrix of coordinates





# create new figure
#fig=plt.figure()
#fig,ax=plt.subplots(figsize=(9,10))
#fig, ax= plt.subplots(nrows=3, ncols=2)
#[axi.set_axis_off() for axi in ax.ravel()]

f = plt.figure(figsize=(24,70))

# panel 1
m=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m(lon,lat)
ax = f.add_subplot(131)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m.contourf(xi,yi,np.squeeze(t1),  cmap='viridis',extend='both') 
m.drawmapboundary()
#m.drawcountries()
m.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m.colorbar(location='bottom', pad="15%")
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
plt.ylabel('Latitude', fontweight='bold', labelpad=35,fontsize=15)
plt.title('R1mm', fontweight='bold', fontsize=16)
ax.text(3.3,3.4, 'R1mm (days)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


# panel 2
m1=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m1(lon,lat)
ax1 = f.add_subplot(132)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m1.contourf(xi,yi,np.squeeze(t2),  cmap='rainbow',extend='both') 
m1.drawmapboundary()
#m1.drawcountries()
m1.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m1.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m1.colorbar(location='bottom', pad="15%")
#cbar.set_ticks([-8,-6,-4,-2,0,2,4,6,8])
cbar.set_ticklabels([-10,-7,-5,-2,0,2,5,7])
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D1-R1mm', fontweight='bold', fontsize=16)
ax1.text(3.3,3.4, 'R1mm (days)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})

# panel 3
ax2 = f.add_subplot(133)
#fig.set_figheight(9)
#fig.set_figwidth(10)
m2=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m2(lon,lat)
cs = m2.contourf(xi,yi,np.squeeze(t3),  cmap='rainbow',extend='both') 
m2.drawmapboundary()
#m2.drawcountries()
m2.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m2.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m2.colorbar(location='bottom', pad="15%")
cbar.set_ticklabels([-7, -5,-2,0,2,5,7,10])
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('mm') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D2-R1mm', fontweight='bold', fontsize=16)
ax2.text(3.3,3.4, 'R1mm (days)', style='italic', fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 2.0, 'pad': 2})


# Show the plot

plt.savefig('/content/drive/MyDrive/extreme_indices/pr9.jpg',bbox_inches='tight')

# %%
### meshgrid ###
lon, lat = np.meshgrid(lons, lats) # create a matrix of coordinates





# create new figure
#fig=plt.figure()
#fig,ax=plt.subplots(figsize=(9,10))
#fig, ax= plt.subplots(nrows=3, ncols=2)
#[axi.set_axis_off() for axi in ax.ravel()]

f = plt.figure(figsize=(24,70))

# panel 1
m=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m(lon,lat)
ax = f.add_subplot(131)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m.contourf(xi,yi,np.squeeze(t1),  cmap='viridis',extend='both') 
m.drawmapboundary()
#m.drawcountries()
m.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m.colorbar(location='bottom', pad="15%")
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
plt.ylabel('Latitude', fontweight='bold', labelpad=35,fontsize=15)
plt.title('R99pTOT', fontweight='bold', fontsize=16)
ax.text(3.3,3.4, 'R99pTOT (mm)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


# panel 2
m1=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m1(lon,lat)
ax1 = f.add_subplot(132)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m1.contourf(xi,yi,np.squeeze(t2),  cmap='rainbow',extend='both') 
m1.drawmapboundary()
#m1.drawcountries()
m1.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m1.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m1.colorbar(location='bottom', pad="15%")
#cbar.set_ticks([-8,-6,-4,-2,0,2,4,6,8])
#cbar.set_ticklabels([-10,-7,-5,-2,0,2,5,7])
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D1-R99pTOT', fontweight='bold', fontsize=16)
ax1.text(3.3,3.4, 'R99pTOT (mm)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})

# panel 3
ax2 = f.add_subplot(133)
#fig.set_figheight(9)
#fig.set_figwidth(10)
m2=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m2(lon,lat)
cs = m2.contourf(xi,yi,np.squeeze(t3),  cmap='rainbow',extend='both') 
m2.drawmapboundary()
#m2.drawcountries()
m2.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m2.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m2.colorbar(location='bottom', pad="15%")
#cbar.set_ticklabels([-7, -5,-2,0,2,5,7,10])
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('mm') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D2-R99pTOT', fontweight='bold', fontsize=16)
ax2.text(3.3,3.4, 'R99pTOT (mm)', style='italic', fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 2.0, 'pad': 2})


# Show the plot

plt.savefig('/content/drive/MyDrive/extreme_indices/pr5.jpg',bbox_inches='tight')

# %%
### meshgrid ###
lon, lat = np.meshgrid(lons, lats) # create a matrix of coordinates





# create new figure
#fig=plt.figure()
#fig,ax=plt.subplots(figsize=(9,10))
#fig, ax= plt.subplots(nrows=3, ncols=2)
#[axi.set_axis_off() for axi in ax.ravel()]

f = plt.figure(figsize=(24,70))

# panel 1
m=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m(lon,lat)
ax = f.add_subplot(131)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m.contourf(xi,yi,np.squeeze(t1),  cmap='viridis',extend='both') 
m.drawmapboundary()
#m.drawcountries()
m.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m.colorbar(location='bottom', pad="15%")
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
plt.ylabel('Latitude', fontweight='bold', labelpad=35,fontsize=15)
plt.title('Rx5day', fontweight='bold', fontsize=16)
ax.text(3.3,3.4, 'Rx5day (mm)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


# panel 2
m1=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m1(lon,lat)
ax1 = f.add_subplot(132)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m1.contourf(xi,yi,np.squeeze(t2),  cmap='rainbow',extend='both') 
m1.drawmapboundary()
#m1.drawcountries()
m1.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m1.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m1.colorbar(location='bottom', pad="15%")
#cbar.set_ticks([-8,-6,-4,-2,0,2,4,6,8])
#cbar.set_ticklabels([-10,-7,-5,-2,0,2,5,7])
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D1-Rx5day', fontweight='bold', fontsize=16)
ax1.text(3.3,3.4, 'Rx5day (mm)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})

# panel 3
ax2 = f.add_subplot(133)
#fig.set_figheight(9)
#fig.set_figwidth(10)
m2=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m2(lon,lat)
cs = m2.contourf(xi,yi,np.squeeze(t3),  cmap='rainbow',extend='both') 
m2.drawmapboundary()
#m2.drawcountries()
m2.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m2.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m2.colorbar(location='bottom', pad="15%")
#cbar.set_ticklabels([-7, -5,-2,0,2,5,7,10])
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('mm') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D2-Rx5day', fontweight='bold', fontsize=16)
ax2.text(3.3,3.4, 'Rx5day (mm)', style='italic', fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 2.0, 'pad': 2})


# Show the plot

plt.savefig('/content/drive/MyDrive/extreme_indices/pr7.jpg',bbox_inches='tight')

# %%
### meshgrid ###
lon, lat = np.meshgrid(lons, lats) # create a matrix of coordinates





# create new figure
#fig=plt.figure()
#fig,ax=plt.subplots(figsize=(9,10))
#fig, ax= plt.subplots(nrows=3, ncols=2)
#[axi.set_axis_off() for axi in ax.ravel()]

f = plt.figure(figsize=(24,70))

# panel 1
m=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m(lon,lat)
ax = f.add_subplot(131)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m.contourf(xi,yi,np.squeeze(t1),  cmap='viridis',extend='both') 
m.drawmapboundary()
#m.drawcountries()
m.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m.colorbar(location='bottom', pad="15%")
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
plt.ylabel('Latitude', fontweight='bold', labelpad=35,fontsize=15)
plt.title('SDII', fontweight='bold', fontsize=16)
ax.text(3.3,3.4, 'SDII (mm/day)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})


# panel 2
m1=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m1(lon,lat)
ax1 = f.add_subplot(132)
#fig.set_figheight(9)
#fig.set_figwidth(10)
cs = m1.contourf(xi,yi,np.squeeze(t2),  cmap='rainbow',extend='both') 
m1.drawmapboundary()
#m1.drawcountries()
m1.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m1.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m1.colorbar(location='bottom', pad="15%")
#cbar.set_ticks([-8,-6,-4,-2,0,2,4,6,8])
#cbar.set_ticklabels([-10,-7,-5,-2,0,2,5,7])
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('days') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D1-SDII', fontweight='bold', fontsize=16)
ax1.text(3.3,3.4, 'SDII (mm/day)', style='italic',fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 2})

# panel 3
ax2 = f.add_subplot(133)
#fig.set_figheight(9)
#fig.set_figwidth(10)
m2=Basemap(projection='cyl',llcrnrlat=3,urcrnrlat=14,llcrnrlon=3,urcrnrlon=14.6,resolution='h')
xi,yi = m2(lon,lat)
cs = m2.contourf(xi,yi,np.squeeze(t3),  cmap='rainbow',extend='both') 
m2.drawmapboundary()
#m2.drawcountries()
m2.drawparallels(np.arange(2, 14, 3), labels=[1,0,0,0],fontsize=16) # draw parallels
m2.drawmeridians(np.arange(3, 15, 3), labels=[0,0,0,1],fontsize=16) # draw meridians
cbar=m2.colorbar(location='bottom', pad="15%")
#cbar.set_ticklabels([-7, -5,-2,0,2,5,7,10])
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontweight="bold",fontsize=16)
#cbar.set_label('mm') # tmean units
plt.xlabel('Longitude', fontweight='bold', labelpad=20,fontsize=16)
#plt.ylabel('Latitude', fontweight='bold', labelpad=25)
plt.title('D2-SDII', fontweight='bold', fontsize=16)
ax2.text(3.3,3.4, 'SDII (mm/day)', style='italic', fontweight="bold",fontsize=12,
        bbox={'facecolor': 'white', 'alpha': 2.0, 'pad': 2})


# Show the plot

plt.savefig('/content/drive/MyDrive/extreme_indices/pr8.jpg',bbox_inches='tight')
